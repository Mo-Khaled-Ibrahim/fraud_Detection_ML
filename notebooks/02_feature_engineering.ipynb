# %% [markdown]
# # 02: Feature Engineering
#
# This notebook performs feature engineering on the raw transaction data and saves the processed data.

# %% [markdown]
# ## Setup

# %%
import sys

# Add features directory to path
sys.path.append('/Workspace/Users/mohamed.c.elshenity@gmail.com/fraud_Detection_ML/src/features')

from static_features import build_static_features
from window_features import build_window_features
from geospatial_features import build_geospatial_features

# %%
from pyspark.sql import SparkSession# Initialize Spark session

spark = SparkSession.builder \
    .appName("FraudDetectionFeatureEngineering") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

print(f"Spark version: {spark.version}")
# Out:
# Spark version: 4.1.0

# %% [markdown]
# ## Load Raw Data

# %%
# Define data paths
raw_data_path = "/Workspace/Users/mohamed.c.elshenity@gmail.com/fraud_Detection_ML/Data"

# Load raw data
df = spark.read.parquet(raw_data_path)

print(f"Raw data loaded: {df.count():,} records")
# Out:
# Raw data loaded: 495,766 records

# %% [markdown]
# ## Build Features

# %%
# Build static features
df = build_static_features(df)
print("Static features built")
# Out:
# Static features built

# %%
# Build window features
df = build_window_features(df)
print("Window features built")
# Out:
# Window features built

# %%
# Build geospatial features
df = build_geospatial_features(df)
print("Geospatial features built")
# Out:
# Geospatial features built

# %% [markdown]
# ## Save Processed Data

# %%
table_name = "fraud_features"
df.write.mode("overwrite").saveAsTable(table_name)

# %%
# %sql
SELECT * FROM fraud_features limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ssn</th><th>cc_num</th><th>first</th><th>last</th><th>gender</th><th>street</th><th>city</th><th>state</th><th>zip</th><th>lat</th><th>long</th><th>city_pop</th><th>job</th><th>dob</th><th>acct_num</th><th>profile</th><th>trans_num</th><th>trans_date</th><th>trans_time</th><th>unix_time</th><th>category</th><th>amt</th><th>is_fraud</th><th>merchant</th><th>merch_lat</th><th>merch_long</th><th>timestamp</th><th>hour</th><th>day_of_week</th><th>month</th><th>distance</th><th>txn_count_1h</th><th>txn_count_24h</th><th>avg_amt_24h</th><th>spend_24h</th><th>unique_merchants_24h</th><th>time_since_last_txn</th><th>haversine_distance</th></tr></thead><tbody><tr><td>409-74-0226</td><td>060401917657</td><td>Sarah</td><td>Stephenson</td><td>F</td><td>4834 Kristen Pass</td><td>Miami</td><td>FL</td><td>33165</td><td>25.7343</td><td>-80.3588</td><td>1737737</td><td>Quarry manager</td><td>1988-11-23</td><td>408510370588</td><td>adults_2550_female_urban.json</td><td>96abba0d99079ce983915f3e3b2c6428</td><td>2024-01-02</td><td>03:19:49</td><td>1704165589</td><td>gas_transport</td><td>34.46</td><td>0</td><td>fraud_Zieme, Bode and Dooley</td><td>24.900497</td><td>-80.697259</td><td>2024-01-02T03:19:49.000Z</td><td>3</td><td>3</td><td>1</td><td>0.8998788460065053</td><td>1</td><td>1</td><td>34.46</td><td>34.46</td><td>1</td><td>null</td><td>98.75903775218163</